# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame

# %%
s = pd.Series([1,2,3,4,5,6,np.nan,8,9,10])

# %%
s
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     9.0
# 9    10.0
# dtype: float64

# %%
d = pd.date_range('20200301', periods=10)
d

# %%
df = pd.DataFrame(np)
