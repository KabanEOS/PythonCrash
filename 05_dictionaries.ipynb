# %%
# DICTIONARIES
student = {'name':'John','age':'25', 'courses':['Math', 'CompSci']}

print(student)
print(student['courses'])
print(student.get('name'))
print(student.get('phone', 'Not Found'))
student['phone'] = '979646313'
# Out:
# {'name': 'John', 'age': '25', 'courses': ['Math', 'CompSci']}
# ['Math', 'CompSci']
# John
# Not Found

# %%
# add
student.update({'name':'Jane', 'age':'12'})

# %%
# update
del student['age']

# %%
# del
print(student.values())
print(student.keys())
# Out:
# {'name': 'Jane', 'courses': ['Math', 'CompSci'], 'phone': '979646313'}
